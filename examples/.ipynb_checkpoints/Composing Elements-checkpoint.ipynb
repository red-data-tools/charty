# %%
# http://holoviews.org/user_guide/Composing_Elements.html

# %%
require 'red-visualizer'

rdv = RdvMain.new(Rdv::Matplot.notebook)
# Out:
# #<RedVisualizer::Main:0x00007ff8ac639e38 @frontend=#<RedVisualizer::Matplot:0x00007ff8ac639e60 @plot=<module 'matplotlib.pyplot' from '/Users/youchan/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/pyplot.py'>>>

# %%
curve = rdv.curve do
  function {|x| Math.sin(x) }
  range({x: (0..10), y: (-1..1)})
end
nil

# %%
curve.render

# %%
scatter = rdv.scatter do
  series 0..10, (0..1).step(0.1)
  range x: 0..10, y: -1..1
end

scatter.render
# Out:
# NoMethodError: undefined method `scatter' for #<RedVisualizer::Main:0x00007ff8ac639e38>
# <main>:in `<main>'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/iruby-0.3/lib/iruby/backend.rb:44:in `eval'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/iruby-0.3/lib/iruby/backend.rb:44:in `eval'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/iruby-0.3/lib/iruby/backend.rb:12:in `eval'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/matplotlib-1.0.0/lib/matplotlib/iruby.rb:60:in `execute_request'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/iruby-0.3/lib/iruby/kernel.rb:47:in `dispatch'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/iruby-0.3/lib/iruby/kernel.rb:37:in `run'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/iruby-0.3/lib/iruby/command.rb:70:in `run_kernel'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/iruby-0.3/lib/iruby/command.rb:34:in `run'
# /Users/youchan/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/iruby-0.3/bin/iruby:5:in `<top (required)>'
# /Users/youchan/.rbenv/versions/2.5.0/bin/iruby:23:in `load'
# /Users/youchan/.rbenv/versions/2.5.0/bin/iruby:23:in `<main>'
